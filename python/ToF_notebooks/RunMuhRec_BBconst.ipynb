# %%
# %%time

import os
import shutil
from subprocess import call
# %matplotlib inline
# Out:
# Wall time: 1.26 s

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is the chosen setting for the paper: constant background read as ExternalBB and the small dose roi in between the two samples.
# ---- THIS ONE USED FOR THE PAPER 

muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_BBconst_dose/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_BBconst_dose/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_BBconst_dose/ReconConfig_bin0103.xml
# Wall time: 50.4 s

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is now a test: constant background read as ExternalBB and the small dose roi in between the two samples
# for the forward scattering of the sample, a pixel by pixel 5% of the sample signal is computed


muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin0000.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin0001.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin0002.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin0003.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin0004.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering/ReconConfig_bin0005.xml
# ...

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is now another test: constant background read as ExternalBB and the small dose roi in between the two samples
# for the forward scattering of the sample, a pixel by pixel 7% of the sample signal is computed


muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_7percent/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_7percent/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_7percent/ReconConfig_bin0129.xml
# Wall time: 1min 1s

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is now another test: constant background read as ExternalBB and the small dose roi in between the two samples
# for the forward scattering of the sample, a pixel by pixel 13% of the sample signal is computed


muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin0000.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin0001.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin0002.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin0003.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin0004.xml
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_13percent/ReconConfig_bin0005.xml
# ...

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is now another test: constant background read as ExternalBB and the small dose roi in between the two samples
# for the forward scattering of the sample, a pixel by pixel 7% of the sample signal and spatially constant is computed


muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_7percent_constd/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_7percent_const/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_7percent_const/ReconConfig_bin0001.xml
# Wall time: 1min 11s

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is now another test: constant background read as ExternalBB and the small dose roi in between the two samples
# for the forward scattering of the sample, a pixel by pixel 5% of the sample signal and spatially constant is computed


muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_5percent_constd/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_5percent_const/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_5percent_const/ReconConfig_bin0000.xml

# %%
# %%time
# Here I run MuhRec in a loop loading the different ReconConfig that I have created in the previous cell
# This is now another test: constant background read as ExternalBB and the small dose roi in between the two samples
# for the forward scattering of the sample, a pixel by pixel 10% of the sample signal and spatially constant is computed


muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_10percent_constd/ReconConfig_bin"+str(0).zfill(4)+".xml"
first_bin=0
last_bin=165

for i in range(first_bin, last_bin):
    cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_10percent_const/ReconConfig_bin"+str(i).zfill(4)+".xml"
    print('Running: ...... ', cfgpath)
    call([muhrec, "-f", cfgpath]) # It does!
# Out:
# Running: ......  D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_configurations_SampleScattering_10percent_const/ReconConfig_bin0130.xml
# Wall time: 49.3 s

# %%
# %%time

#Reconstruct again without BB and wihtout dose to see if the bump goes away
projpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/"
destpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_nodose" 
# path to the application
muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
# cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/Recon_WhiteBeam/ReconConfig.xml"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_WhiteBeam_noBB_nodose/ReconConfig.xml"
#first try
# filemask ="projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned/IMAT_tomo_binned_00000.fits"
# obmask ="projections:obfilemask=D:/Kaestner/ISIS_IAEAData\RB1730015/Tomo_test_RB1730044/OpenBeam_aft#_Corrected_Binned/IMAT_ob_binned_00000.fits"
obfirstindex ="projections:obfirstindex=2"
obcount ="projections:obcount=2"
# path = r"/bin0000"
# outputpath="matrix:path="+destpath+path

# print(outputpath)



first_bin=0
last_bin=165
for i in range(first_bin, last_bin):
    filemask ="projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned/IMAT_tomo_binned_"+str(i).zfill(5)+".fits"
    path = r"/bin"+str(i).zfill(4)
    outputpath="matrix:path="+destpath+path

    obmask ="projections:obfilemask=D:/Kaestner/ISIS_IAEAData/RB1730015/Tomo_test_RB1730044/OpenBeam_aft#_Corrected_Binned/IMAT_tomo_binned_"+str(i).zfill(5)+".fits"
    print(filemask)
    print(outputpath)
#     print(obmask)

    if not os.path.exists(destpath+path):
        os.makedirs(destpath+path)

#     print(muhrec)
#     print(cfgpath)
    call([muhrec, "-f", cfgpath, filemask, obmask, obfirstindex, obcount, outputpath])
# Out:
# projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned/IMAT_tomo_binned_00000.fits
# matrix:path=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_nodose/bin0000
# projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned/IMAT_tomo_binned_00001.fits
# matrix:path=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_nodose/bin0001
# projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned/IMAT_tomo_binned_00002.fits
# matrix:path=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_nodose/bin0002
# ...

# %%
# %%time
# Here I run MuhRec with presubtracted background images

#Reconstruct again without BB and wihtout dose to see if the bump goes away
projpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/"
# destpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_nodose" 
destpath = 'D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_249_MinusBack_nodose'
# path to the application
muhrec=r"C:/Users/carminati_c/muhrec/muhrecCLI.exe"
# cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/Recon_WhiteBeam/ReconConfig.xml"
cfgpath=r"D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_WhiteBeam_noBB_nodose/ReconConfig.xml"

obfirstindex ="projections:obfirstindex=2"
obcount ="projections:obcount=2"
first_bin=0
last_bin=165
for i in range(first_bin, last_bin):
    filemask ="projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned_MinusBack/IMAT_tomo_binned_"+str(i).zfill(5)+".fits"
    path = r"/bin"+str(i).zfill(4)
    outputpath="matrix:path="+destpath+path

    obmask ="projections:obfilemask=D:/Kaestner/ISIS_IAEAData/RB1730015/Tomo_test_RB1730044/OpenBeam_aft#_Corrected_Binned_MinusBack/IMAT_tomo_binned_"+str(i).zfill(5)+".fits"
    print(filemask)
    print(outputpath)
#     print(obmask)

    if not os.path.exists(destpath+path):
        os.makedirs(destpath+path)

#     print(muhrec)
#     print(cfgpath)
    call([muhrec, "-f", cfgpath, filemask, obmask, obfirstindex, obcount, outputpath])
# Out:
# projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned_MinusBack/IMAT_tomo_binned_00000.fits
# matrix:path=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_249_MinusBack_nodose/bin0000
# projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned_MinusBack/IMAT_tomo_binned_00001.fits
# matrix:path=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_249_MinusBack_nodose/bin0001
# projections:filemask=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle####_Corrected_Binned_MinusBack/IMAT_tomo_binned_00002.fits
# matrix:path=D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/CT_recon_binSum_165bin_249_MinusBack_nodose/bin0002
# ...
