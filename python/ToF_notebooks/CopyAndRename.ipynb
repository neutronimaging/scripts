# %% [markdown]
# # I copy and rename the whitebeam images to reconstruct it with MuhRec

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import fits
import os, fnmatch
from os import listdir
from scipy import ndimage
import shutil

#%matplotlib inline
# %matplotlib notebook

# %%
path_folders = "D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/"
list_folders = sorted(fnmatch.filter(os.listdir(path_folders),'*_Corrected'))
print(list_folders)
# Out:
# ['angle0000_Corrected', 'angle0001_Corrected', 'angle0002_Corrected', 'angle0003_Corrected', 'angle0004_Corrected', 'angle0005_Corrected', 'angle0006_Corrected', 'angle0007_Corrected', 'angle0008_Corrected', 'angle0009_Corrected', 'angle0010_Corrected', 'angle0011_Corrected', 'angle0012_Corrected', 'angle0013_Corrected', 'angle0014_Corrected', 'angle0015_Corrected', 'angle0016_Corrected', 'angle0017_Corrected', 'angle0018_Corrected', 'angle0019_Corrected', 'angle0020_Corrected', 'angle0021_Corrected', 'angle0022_Corrected', 'angle0023_Corrected', 'angle0024_Corrected', 'angle0025_Corrected', 'angle0026_Corrected', 'angle0027_Corrected', 'angle0028_Corrected', 'angle0029_Corrected', 'angle0030_Corrected', 'angle0031_Corrected', 'angle0032_Corrected', 'angle0033_Corrected', 'angle0034_Corrected', 'angle0035_Corrected', 'angle0036_Corrected', 'angle0037_Corrected', 'angle0038_Corrected', 'angle0039_Corrected', 'angle0040_Corrected', 'angle0041_Corrected', 'angle0042_Corrected', 'angle00
# ...

# %%
folder_output =  "D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/WhiteBeam"

if not os.path.exists(folder_output):
    os.makedirs(folder_output)

# %%
for i in range(0, len(list_folders)):
    old_file_name ='IMAT_tomo_SummedImg.fits'
    src_file = os.path.join(path_folders+list_folders[i], old_file_name)
    shutil.copy(src_file,folder_output)
#     print(src_file)
    dst_file = os.path.join(folder_output, old_file_name)
#     print(dst_file)
    new_file_name = 'IMAT_tomo_SummedImg'+list_folders[i][5:9]+'.fits'
#     print(new_file_name)
    new_dst_file_name = os.path.join(folder_output, new_file_name)
    print(src_file, new_dst_file_name)
    os.rename(dst_file, new_dst_file_name)
# Out:
# D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle0000_Corrected\IMAT_tomo_SummedImg.fits D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/WhiteBeam\IMAT_tomo_SummedImg0000.fits
# D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle0001_Corrected\IMAT_tomo_SummedImg.fits D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/WhiteBeam\IMAT_tomo_SummedImg0001.fits
# D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/angle0002_Corrected\IMAT_tomo_SummedImg.fits D:/Kaestner/ISIS_IAEAData/RB1730044/PSI_Cylinder/Sample/RB1730044/Tomo_test/Sample/WhiteBeam\IMAT_tomo_SummedImg0002.fits
# ...
